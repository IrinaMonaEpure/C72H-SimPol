# %%
from pathlib import Path
import sys

sys.path.append(
    str(Path.cwd().parent)
)

# %%
from src import (
    plot_all_correlation_distributions,
    plot_first_column_sums
)

# %%
# Corr distrib
plot_all_correlation_distributions(
    folder="../output/country_networks/correlation",
    output_path="../plots/correlation/all_weight_distributions.png",
    pattern="*correlation*.pkl",
)

sums = plot_first_column_sums(
    folder=".../output/country_networks/correlation",
    output_plot_path="../plots/correlation/first_column_sums.png",
    output_table_path="../output/correlation/first_column_sums.csv",
    output_first_columns_plot_path="../plots/correlation/first_column_weights_all_countries.png",
    pattern="correlation_*.pkl",
)

# %%
# Partial corr distrib
plot_all_correlation_distributions(
    folder="../output/country_networks/partial_correlation",
    output_path="../plots/partial_correlation/all_weight_distributions.png",
    pattern="*correlation*.pkl",
)

sums = plot_first_column_sums(
    folder=".../output/country_networks/partial_correlation",
    output_plot_path="../plots/partial_correlation/first_column_sums.png",
    output_table_path="../output/partial_correlation/first_column_sums.csv",
    output_first_columns_plot_path="../plots/partial_correlation/first_column_weights_all_countries.png",
    pattern="partial_correlation_*.pkl",
)

# %%
# Peixoto
plot_all_correlation_distributions(
    folder="../output/networks",
    output_path="../plots/peixoto/all_weight_distributions.png",
    pattern="*.graphml",
)

sums = plot_first_column_sums(
    folder="../output/networks",
    output_plot_path="../plots/peixoto/first_column_sums.png",
    output_table_path="../output/peixoto/first_column_sums.csv",
    output_first_columns_plot_path="../plots/peixoto/first_column_weights_all_countries.png",
    pattern="*.pkl",
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Peixoto
# ----> 2 plot_all_correlation_distributions(
#       3     folder="../output/networks",
#       4     output_path="../plots/peixoto/all_weight_distributions.png",
#       5     pattern="*.pkl",
#
# File ~/Complexity72H/C72H-SimPol/inference/src/aggregate_plots.py:68, in plot_all_correlation_distributions(folder, output_path, pattern, bins, extensions, title, show)
#      62 paths = sorted(
#      63     p for p in folder.glob(pattern)
#      64     if p.suffix.lower() in extensions
#      65 )
#      67 if not paths:
# ---> 68     raise ValueError(f"No supported weight files found in {folder}")
#      70 loaded = []
#      72 for path in paths:
#
# ValueError: No supported weight files found in ../output/networks
