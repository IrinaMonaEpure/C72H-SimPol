# %%
from pathlib import Path
import sys

sys.path.append(
    str(Path.cwd().parent)
)

# %%
from src import (
    plot_all_correlation_distributions,
    plot_first_column_averages,
    plot_total_correlation_summaries,
    save_top_beliefs_by_absolute_edge_sum,
    plot_near_zero_correlation_counts,
    plot_first_column_average_with_dendrogram
)

# %%
# Corr distrib
plot_all_correlation_distributions(
    folder="../output/country_networks/correlation",
    output_path="../plots/aggregate/correlation/all_weight_distributions.png",
    pattern="*correlation*.pkl",
)

averages = plot_first_column_averages(
    folder="../output/country_networks/correlation",
    output_plot_path="../plots/aggregate/correlation/first_column_avg.png",
    output_table_path="../plots/aggregate/correlation/first_column_avg.csv",
    output_first_columns_plot_path="../plots/aggregate/correlation/first_column_weights_all_countries.png",
    pattern="*correlation*.pkl",
)

sums = plot_total_correlation_summaries(
    folder="../output/country_networks/correlation",
    output_signed_plot_path="../plots/aggregate/correlation/signed_correlation_sums.png",
    output_absolute_plot_path="../plots/aggregate/correlation/absolute_correlation_sums.png",
    output_table_path="../plots/aggregate/correlation/correlation_sums.csv",
    pattern="correlation_*.pkl",
)

top_beliefs = save_top_beliefs_by_absolute_edge_sum(
    folder="../output/country_networks/correlation",
    output_csv_path="../plots/aggregate/correlation/top_5_correlation_beliefs_by_country_without_left_righ_identification.csv",
    pattern="correlation_*.pkl",
    top_n=5,
    ignore_belief="left_right_identification",
)

plot_near_zero_correlation_counts(
    folder="../output/country_networks/correlation",
    output_plot_path="../plots/aggregate/correlation/near_zero_counts.png",
    output_csv_path="../plots/aggregate/correlation/near_zero_counts.csv",
    pattern="correlation_*.pkl",
    zero_threshold=0.025,
)

# %%
# Partial corr distrib
plot_all_correlation_distributions(
    folder="../output/country_networks/partial_correlation",
    output_path="../plots/aggregate/partial_correlation/all_weight_distributions.png",
    pattern="*correlation*.pkl",
)

averages = plot_first_column_averages(
    folder="../output/country_networks/partial_correlation",
    output_plot_path="../plots/aggregate/partial_correlation/first_column_avg.png",
    output_table_path="../plots/aggregate/partial_correlation/first_column_avg.csv",
    output_first_columns_plot_path="../plots/aggregate/partial_correlation/first_column_weights_all_countries.png",
    pattern="partial_correlation_*.pkl",
)

sums = plot_total_correlation_summaries(
    folder="../output/country_networks/partial_correlation",
    output_signed_plot_path="../plots/aggregate/partial_correlation/signed_correlation_sums.png",
    output_absolute_plot_path="../plots/aggregate/partial_correlation/absolute_correlation_sums.png",
    output_table_path="../plots/aggregate/partial_correlation/correlation_sums.csv",
    pattern="partial_correlation_*.pkl",
)

top_beliefs = save_top_beliefs_by_absolute_edge_sum(
    folder="../output/country_networks/partial_correlation",
    output_csv_path="../plots/aggregate/partial_correlation/top_5_correlation_beliefs_by_country_without_left_righ_identification.csv",
    pattern="partial_correlation_*.pkl",
    top_n=5,
    ignore_belief="left_right_identification",
)

plot_near_zero_correlation_counts(
    folder="../output/country_networks/partial_correlation",
    output_plot_path="../plots/aggregate/partial_correlation/near_zero_counts.png",
    output_csv_path="../plots/aggregate/partial_correlation/near_zero_counts.csv",
    pattern="partial_correlation_*.pkl",
    zero_threshold=0.025,
)

# %%
# Peixoto
plot_all_correlation_distributions(
    folder="../output/networks",
    output_path="../plots/aggregate/peixoto/all_weight_distributions.png",
    pattern="*.graphml",
)

averages = plot_first_column_averages(
    folder="../output/networks",
    output_plot_path="../plots/aggregate/peixoto/first_column_avg.png",
    output_table_path="../plots/aggregate/peixoto/first_column_avg.csv",
    output_first_columns_plot_path="../plots/aggregate/peixoto/first_column_weights_all_countries.png",
    pattern="*.graphml",
)

sums = plot_total_correlation_summaries(
    folder="../output/networks",
    output_signed_plot_path="../plots/aggregate/peixoto/signed_correlation_sums.png",
    output_absolute_plot_path="../plots/aggregate/peixoto/absolute_correlation_sums.png",
    output_table_path="../plots/aggregate/peixoto/correlation_sums.csv",
    pattern="*.graphml",
)

top_beliefs = save_top_beliefs_by_absolute_edge_sum(
    folder="../output/networks",
    output_csv_path="../plots/aggregate/peixoto/top_5_correlation_beliefs_by_country_without_left_righ_identification.csv",
    pattern="*.graphml",
    top_n=5,
    ignore_belief="left_right_identification",
)

plot_near_zero_correlation_counts(
    folder="../output/networks",
    output_plot_path="../plots/aggregate/peixoto/near_zero_counts.png",
    output_csv_path="../plots/aggregate/peixoto/near_zero_counts.csv",
    pattern="*.graphml",
    zero_threshold=0.025,
)

# %%
# Peixoto correlation matrix columns with dendrogram
result = plot_first_column_average_with_dendrogram(
    folder="../output/networks",
    dendrogram_csv="../plots/aggregate/peixoto/dendrogram_linkage.csv",
    output_plot_path="../plots/aggregate/peixoto/first_column_avg.png",
    output_table_path="../plots/aggregate/peixoto/first_column_avg.csv",
    output_first_columns_plot_path="../plots/aggregate/peixoto/first_columns_with_dendrogram.png",
    pattern="*.graphml",
)
# Out:
# /home/irina/Complexity72H/C72H-SimPol/inference/src/aggregate_plots.py:1182: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
